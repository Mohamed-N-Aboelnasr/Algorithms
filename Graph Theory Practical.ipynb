# %% [markdown]
# <center>
#     <h1>Mohamed Nasser Aboelnasr</h1>
# </center>

# %% [markdown]
# # Implementation of the directed graph using adjacency list

# %%
def addVertex(v,graph):
    if v in graph:
        print("vertex",v,"is already in the graph!")
    else:
        graph[v]=[]

def addEdge(v1,v2,w,graph):
    if v1 not in graph:
        print("vertex",v1,"doesn't exist!")
    elif v2 not in graph:
        print("vertex",v2,"doesn't exist!")
    else:
        graph[v1].append([v2,w])

def printGraph(graph):
    for vertex in graph:
        for edge in graph[vertex]:
            print("vertex",vertex,"---->","vertex",edge[0],"Edge's weight :",edge[1])

# %%
graph = {}
addVertex(1,graph)
addVertex(2,graph)
addVertex(3,graph)
addVertex(4,graph)
addEdge(1, 2, 1,graph)
addEdge(1, 3, 1,graph)
addEdge(2, 3, 3,graph)
addEdge(3, 4, 4,graph)
addEdge(4, 1, 5,graph)
printGraph(graph)
print(graph)
# Out:
# vertex 1 ----> vertex 2 Edge's weight : 1
# vertex 1 ----> vertex 3 Edge's weight : 1
# vertex 2 ----> vertex 3 Edge's weight : 3
# vertex 3 ----> vertex 4 Edge's weight : 4
# vertex 4 ----> vertex 1 Edge's weight : 5
# {1: [[2, 1], [3, 1]], 2: [[3, 3]], 3: [[4, 4]], 4: [[1, 5]]}

# %%
graph2 = {}
addVertex(1,graph2)
addVertex(2,graph2)
addVertex(3,graph2)
addVertex(4,graph2)
addEdge(1, 2, 7,graph2)
addEdge(1, 4, 5,graph2)
addEdge(2, 3, 2,graph2)
addEdge(3, 4, 6,graph2)
printGraph(graph2)
print(graph2)
# Out:
# vertex 1 ----> vertex 2 Edge's weight : 7
# vertex 1 ----> vertex 4 Edge's weight : 5
# vertex 2 ----> vertex 3 Edge's weight : 2
# vertex 3 ----> vertex 4 Edge's weight : 6
# {1: [[2, 7], [4, 5]], 2: [[3, 2]], 3: [[4, 6]], 4: []}

# %% [markdown]
# # Implementation of the undirected graph using adjacency list

# %%
def addVertex(v,graph):
    if v in graph:
        print("vertex",v,"is already in the graph!")
    else:
        graph[v]=[]

def addEdge(v1,v2,w,graph):
    if v1 not in graph:
        print("vertex",v1,"doesn't exist!")
    elif v2 not in graph:
        print("vertex",v2,"doesn't exist!")
    else:
        graph[v1].append([v2,w])
        graph[v2].append([v1,w])


def printGraph(graph):
    for vertex in graph:
        for edge in graph[vertex]:
            print("vertex",vertex,"---->","vertex",edge[0],"Edge's weight :",edge[1])

# %%
graph = {}
addVertex(1,graph)
addVertex(2,graph)
addVertex(3,graph)
addVertex(4,graph)
addEdge(1, 2, 1,graph)
addEdge(1, 3, 1,graph)
addEdge(2, 3, 3,graph)
addEdge(3, 4, 4,graph)
addEdge(4, 1, 5,graph)
printGraph(graph)
print(graph)
# Out:
# vertex 1 ----> vertex 2 Edge's weight : 1
# vertex 1 ----> vertex 3 Edge's weight : 1
# vertex 1 ----> vertex 4 Edge's weight : 5
# vertex 2 ----> vertex 1 Edge's weight : 1
# vertex 2 ----> vertex 3 Edge's weight : 3
# vertex 3 ----> vertex 1 Edge's weight : 1
# vertex 3 ----> vertex 2 Edge's weight : 3
# vertex 3 ----> vertex 4 Edge's weight : 4
# vertex 4 ----> vertex 3 Edge's weight : 4
# vertex 4 ----> vertex 1 Edge's weight : 5
# {1: [[2, 1], [3, 1], [4, 5]], 2: [[1, 1], [3, 3]], 3: [[1, 1], [2, 3], [4, 4]], 4: [[3, 4], [1, 5]]}

# %%
graph2 = {}
addVertex(1,graph2)
addVertex(2,graph2)
addVertex(3,graph2)
addVertex(4,graph2)
addEdge(1, 2, 7,graph2)
addEdge(1, 4, 5,graph2)
addEdge(2, 3, 2,graph2)
addEdge(3, 4, 6,graph2)
printGraph(graph2)
print(graph2)
# Out:
# vertex 1 ----> vertex 2 Edge's weight : 7
# vertex 1 ----> vertex 4 Edge's weight : 5
# vertex 2 ----> vertex 1 Edge's weight : 7
# vertex 2 ----> vertex 3 Edge's weight : 2
# vertex 3 ----> vertex 2 Edge's weight : 2
# vertex 3 ----> vertex 4 Edge's weight : 6
# vertex 4 ----> vertex 1 Edge's weight : 5
# vertex 4 ----> vertex 3 Edge's weight : 6
# {1: [[2, 7], [4, 5]], 2: [[1, 7], [3, 2]], 3: [[2, 2], [4, 6]], 4: [[1, 5], [3, 6]]}

# %% [markdown]
# # Implementation of the directed graph using adjacency matrix

# %%
def addVertex(v,graph):
    if v <= len(graph):
        print("The vertex already exists!")
    elif v > (len(graph)+1):
        print("There is no vertex ",(len(graph)+1),"you must add it before adding vertex",v)
    else:
        if not graph:
            graph.append([0])
        else:
            for vertex in graph:
                vertex.append(0)
            graph.append([0]*len(graph[0]))

def addEdge(v1,v2,w,graph):
    if v1 > len(graph):
        print("vertex",v1,"doesn't exist!")
    elif v2 > len(graph):
        print("vertex",v2,"doesn't exist!")
    else:
        graph[v1-1][v2-1]=w
        
def printGraph(graph):
    for source in range(len(graph)):
        for destination in range(len(graph)):
            if graph[source][destination] != 0:
                print("vertex",source+1,"---->","vertex",destination+1,"Edge's weight :",graph[source][destination])

# %%
graph = []
addVertex(1,graph)
addVertex(2,graph)
addVertex(3,graph)
addVertex(4,graph)
addEdge(1, 2, 1,graph)
addEdge(1, 3, 1,graph)
addEdge(2, 3, 3,graph)
addEdge(3, 4, 4,graph)
addEdge(4, 1, 5,graph)
printGraph(graph)
print(graph)
# Out:
# vertex 1 ----> vertex 2 Edge's weight : 1
# vertex 1 ----> vertex 3 Edge's weight : 1
# vertex 2 ----> vertex 3 Edge's weight : 3
# vertex 3 ----> vertex 4 Edge's weight : 4
# vertex 4 ----> vertex 1 Edge's weight : 5
# [[0, 1, 1, 0], [0, 0, 3, 0], [0, 0, 0, 4], [5, 0, 0, 0]]

# %%
graph2 = []
addVertex(1,graph2)
addVertex(2,graph2)
addVertex(3,graph2)
addVertex(4,graph2)
addEdge(1, 2, 7,graph2)
addEdge(1, 4, 5,graph2)
addEdge(2, 3, 2,graph2)
addEdge(3, 4, 6,graph2)
printGraph(graph2)
print(graph2)
# Out:
# vertex 1 ----> vertex 2 Edge's weight : 7
# vertex 1 ----> vertex 4 Edge's weight : 5
# vertex 2 ----> vertex 3 Edge's weight : 2
# vertex 3 ----> vertex 4 Edge's weight : 6
# [[0, 7, 0, 5], [0, 0, 2, 0], [0, 0, 0, 6], [0, 0, 0, 0]]

# %% [markdown]
# # Implementation of the undirected graph using adjacency matrix

# %%
def addVertex(v,graph):
    if v <= len(graph):
        print("The vertex already exists!")
    elif v > (len(graph)+1):
        print("There is no vertex ",(len(graph)+1),"you must add it before adding vertex",v)
    else:
        if not graph:
            graph.append([0])
        else:
            for vertex in graph:
                vertex.append(0)
            graph.append([0]*len(graph[0]))

def addEdge(v1,v2,w,graph):
    if v1 > len(graph):
        print("vertex",v1,"doesn't exist!")
    elif v2 > len(graph):
        print("vertex",v2,"doesn't exist!")
    else:
        graph[v1-1][v2-1]=w
        graph[v2-1][v1-1]=w
        
def printGraph(graph):
    for source in range(len(graph)):
        for destination in range(len(graph)):
            if graph[source][destination] != 0:
                print("vertex",source+1,"---->","vertex",destination+1,"Edge's weight :",graph[source][destination])

# %%
graph = []
addVertex(1,graph)
addVertex(2,graph)
addVertex(3,graph)
addVertex(4,graph)
addEdge(1, 2, 1,graph)
addEdge(1, 3, 1,graph)
addEdge(2, 3, 3,graph)
addEdge(3, 4, 4,graph)
addEdge(4, 1, 5,graph)
printGraph(graph)
print(graph)
# Out:
# vertex 1 ----> vertex 2 Edge's weight : 1
# vertex 1 ----> vertex 3 Edge's weight : 1
# vertex 1 ----> vertex 4 Edge's weight : 5
# vertex 2 ----> vertex 1 Edge's weight : 1
# vertex 2 ----> vertex 3 Edge's weight : 3
# vertex 3 ----> vertex 1 Edge's weight : 1
# vertex 3 ----> vertex 2 Edge's weight : 3
# vertex 3 ----> vertex 4 Edge's weight : 4
# vertex 4 ----> vertex 1 Edge's weight : 5
# vertex 4 ----> vertex 3 Edge's weight : 4
# [[0, 1, 1, 5], [1, 0, 3, 0], [1, 3, 0, 4], [5, 0, 4, 0]]

# %%
graph2 = []
addVertex(1,graph2)
addVertex(2,graph2)
addVertex(3,graph2)
addVertex(4,graph2)
addEdge(1, 2, 7,graph2)
addEdge(1, 4, 5,graph2)
addEdge(2, 3, 2,graph2)
addEdge(3, 4, 6,graph2)
printGraph(graph2)
print(graph2)
# Out:
# vertex 1 ----> vertex 2 Edge's weight : 7
# vertex 1 ----> vertex 4 Edge's weight : 5
# vertex 2 ----> vertex 1 Edge's weight : 7
# vertex 2 ----> vertex 3 Edge's weight : 2
# vertex 3 ----> vertex 2 Edge's weight : 2
# vertex 3 ----> vertex 4 Edge's weight : 6
# vertex 4 ----> vertex 1 Edge's weight : 5
# vertex 4 ----> vertex 3 Edge's weight : 6
# [[0, 7, 0, 5], [7, 0, 2, 0], [0, 2, 0, 6], [5, 0, 6, 0]]

# %% [markdown]
# # Implementation of breadth-first search

# %%
def bfs(graph,root):
    visited=[]
    queue=[]
    visited.append(root)
    queue.append(root)
    while queue:
        node=queue.pop(0)
        print(node,end=' ')
        for neighbor in graph[node]:
            if neighbor not in visited:
                visited.append(neighbor)
                queue.append(neighbor)

# %% [markdown]
# ## Example from lecture

# %% [markdown]
# ![ex.png](attachment:ex.png)

# %%
graph = {
  'a' : ['b','c'],
  'b' : ['f'],
  'c' : ['f','e'],
  'd' : ['c'],
  'e' : ['d','h','i'],
  'f' : ['g','h'],
  'g' : ['b'],
  'h' : ['e'],
  'i' : ['h'],
}

bfs(graph,'a')
# Out:
# a b c f e g h d i

# %% [markdown]
# # Implementation of depth-first search using OOP

# %%
class Node:
    
    def __init__(self,val):
        self.left=None
        self.right=None
        self.value=val
        
def preorderTraverse(root):
    if root:
        print(root.value,end=' ')
        preorderTraverse(root.left)
        preorderTraverse(root.right)

def inorderTraverse(root):
    if root:
        inorderTraverse(root.left)
        print(root.value,end=' ')
        inorderTraverse(root.right)

def postorderTraverse(root):
    if root:
        postorderTraverse(root.left)
        postorderTraverse(root.right)
        print(root.value,end=' ')

# %% [markdown]
# ![ex2.png](attachment:ex2.png)

# %%
root = Node('F')
root.left = Node('B')
root.right = Node('G')
root.left.left = Node('A')
root.left.right = Node('D')
root.left.right.left=Node('C')
root.left.right.right=Node('E')
root.right.right=Node('I')
root.right.right.left=Node('H')

# %%
print("Preorder traversal of binary tree : ")
preorderTraverse(root)
# Out:
# Preorder traversal of binary tree :
# F B A D C E G I H

# %%
print("Inorder traversal of binary tree : ")
inorderTraverse(root)
# Out:
# Inorder traversal of binary tree :
# A B C D E F G H I

# %%
print("Postorder traversal of binary tree : ")
postorderTraverse(root)
# Out:
# Postorder traversal of binary tree :
# A C E D B H I G F
